# %% [markdown]
# # Análisis exploratorio (EDA)

# %% [markdown]
# ## Librerías e información de dataset

# %%
# importar librerias necesarias
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# carga de datos y primera visualización
df = pd.read_csv("/Users/samanthaestudillo/Documents/No Country/hackaton h4-05/h4-05-fintech/data/data/processed/financial_profile_iupi.csv")
df.head()
# Out:
#       first_name last_name      id                         email  user_id  \
# 0        Azucena    Ayllón  718919       Rixjomh.povna@gmail.com   718919
# 1  Andrés felipe   Rodrigo  797826      Cvlisikp.boeaf@yahoo.com   797826
# 2           Amor  Figueras  617096       Dcii.cmmvcq@outlook.com   617096
# 3            Paz   Vicente  957587  Qcepsmwb.xhvukxg@hotmail.com   957587
# 4       Epifanio    Alemán  120636          Rknj.rumyz@gmail.com   120636
#
#    age                    occupation financial_goals risk_tolerance  \
# 0   69  Controlador de tráfico aéreo        Vivienda       Moderado
# 1   38                     Filósofos      Vacaciones    Conservador
# 2   69                         Otros        Vivienda     Arriesgado
# 3   48                         Otros      Jubilación     Arriesgado
# 4   24                      Agrónomo        Vivienda    Conservador
#
#   financial_preference financial_options financial_knowledge  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   first_name            500 non-null    object
#  1   last_name             500 non-null    object
#  2   id                    500 non-null    int64
#  3   email                 500 non-null    object
#  4   user_id               500 non-null    int64
#  5   age                   500 non-null    int64
#  6   occupation            500 non-null    object
#  7   financial_goals       500 non-null    object
#  8   risk_tolerance        500 non-null    object
#  9   financial_preference  500 non-null    object
#  10  financial_options     500 non-null    object
#  11  financial_knowledge   500 non-null    object
#  12  investment_period     500 non-null    int64
#  13  income_source         500 non-null    object
#  14  income_average        500 non-null    int64
# ...

# %% [markdown]
# ## Distribucion de variables numéricas

# %%
# análisis de distribuciones
num_cols = ['age', 'investment_period', 'income_average', 'expenses_average', 'monthly_contribution']
for col in num_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], bins=30, kde=True, color='skyblue')
    plt.title(f"Distribución de {col}")
    plt.xlabel(col)
    plt.ylabel("Frecuencia")
    plt.show()

# %% [markdown]
# ## Distribución de varibles categóricas

# %%
# distribución de datos categóricos
cat_cols = ['financial_goals', 'risk_tolerance', 'financial_preference', 'financial_options', 'financial_knowledge', 'income_source', 'saving_plan']
for col in cat_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, y=col, order=df[col].value_counts().index)
    plt.title(f"Distribución de {col}")
    plt.show()

# %% [markdown]
# ## Correlación

# %%
# relaciones entre variables
correlation_matrix = df[num_cols].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlación entre variables numéricas")
plt.show()

# %% [markdown]
# ## Valores atípicos

# %%
# gráfico para identificar valores atípicos
for col in num_cols:
    plt.figure(figsize=(8, 5))
    sns.scatterplot(x=df.index, y=df[col], color="royalblue", alpha=0.6)
    plt.title(f"Dispersión de {col} para detección de outliers")
    plt.xlabel("Índice del dato")
    plt.ylabel(col)
    plt.show()
