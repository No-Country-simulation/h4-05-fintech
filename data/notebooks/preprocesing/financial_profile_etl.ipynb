# %% [markdown]
# # Preprocesamiento de datos: Limpieza, formateo y validación del conjunto de datos

# %% [markdown]
# ## Librerías

# %%
# importar librerias necesarias
import pandas as pd 
from faker import Faker

# %% [markdown]
# ## Dataset

# %%
# carga de datos y primera visualización
df = pd.read_csv("/Users/samanthaestudillo/Documents/No Country/hackaton h4-05/h4-05-fintech/data/data/raw/financial_profiles_argentina.csv")
df.head()
# Out:
#     Nombres Apellidos      id                         email  user_id  age  \
# 0   Rixjomh     Povna  718919       rixjomh.povna@gmail.com   718919   69
# 1  Cvlisikp     Boeaf  797826      cvlisikp.boeaf@yahoo.com   797826   38
# 2      Dcii    Cmmvcq  617096       dcii.cmmvcq@outlook.com   617096   69
# 3  Qcepsmwb   Xhvukxg  957587  qcepsmwb.xhvukxg@hotmail.com   957587   48
# 4      Rknj     Rumyz  120636          rknj.rumyz@gmail.com   120636   24
#
#                      occupation FinancialGoals RiskTolerance  \
# 0  Controlador de tráfico aéreo       VIVIENDA      MODERADO
# 1                     Filósofos     VACACIONES   CONSERVADOR
# 2                           NaN       VIVIENDA    ARRIESGADO
# 3                           NaN     JUBILACION    ARRIESGADO
# 4                      Agrónomo       VIVIENDA   CONSERVADOR
#
#   FinancialPreference FinancialOptions FinalKnowledge target_period  \
# 0              AHORRO              NaN       AVANZADO         1 año
# 1              AHORRO              NaN     INTERMEDIO       10 años
# 2           INVERSION            OTROS        NINGUNO       5 meses
# 3           INVERSION             ETFS        NINGUNO       5 meses
# 4           INVERSION         ACCIONES         BASICO         1 año
#
#   income_source  income_average  expenses_average saving_plan  contribution
# 0   dependiente          548843            412840          NO            40
# 1         ambos          823536            473397          SI            98
# 2   dependiente          828342            485594          NO            59
# 3   dependiente          868632            506774          NO            39
# 4         ambos          824883            772137          SI            13

# %%
# tamaño del dataset 
df.shape
# Out:
# (500, 18)

# %%
# información general del dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Nombres              500 non-null    object
#  1   Apellidos            500 non-null    object
#  2   id                   500 non-null    int64
#  3   email                500 non-null    object
#  4   user_id              500 non-null    int64
#  5   age                  500 non-null    int64
#  6   occupation           454 non-null    object
#  7   FinancialGoals       500 non-null    object
#  8   RiskTolerance        500 non-null    object
#  9   FinancialPreference  500 non-null    object
#  10  FinancialOptions     250 non-null    object
#  11  FinalKnowledge       500 non-null    object
#  12  target_period        500 non-null    object
#  13  income_source        500 non-null    object
#  14  income_average       500 non-null    int64
#  15  expenses_average     500 non-null    int64
#  16  saving_plan          500 non-null    object
#  17  contribution         500 non-null    int64
# dtypes: int64(6), object(12)
# memory usage: 70.4+ KB

# %%
# estandarizar columnas con formato snake case 
df.rename(columns={
    'Nombres': 'first_name',
    'Apellidos': 'last_name',
    'FinancialGoals': 'financial_goals',
    'RiskTolerance': 'risk_tolerance',
    'FinancialPreference': 'financial_preference',
    'FinancialOptions': 'financial_options',
    'FinalKnowledge': 'financial_knowledge',
    'target_period': 'investment_period',
    'contribution': 'monthly_contribution'
}, inplace=True)

df.head()
# Out:
#   first_name last_name      id                         email  user_id  age  \
# 0    Rixjomh     Povna  718919       rixjomh.povna@gmail.com   718919   69
# 1   Cvlisikp     Boeaf  797826      cvlisikp.boeaf@yahoo.com   797826   38
# 2       Dcii    Cmmvcq  617096       dcii.cmmvcq@outlook.com   617096   69
# 3   Qcepsmwb   Xhvukxg  957587  qcepsmwb.xhvukxg@hotmail.com   957587   48
# 4       Rknj     Rumyz  120636          rknj.rumyz@gmail.com   120636   24
#
#                      occupation financial_goals risk_tolerance  \
# 0  Controlador de tráfico aéreo        VIVIENDA       MODERADO
# 1                     Filósofos      VACACIONES    CONSERVADOR
# 2                           NaN        VIVIENDA     ARRIESGADO
# 3                           NaN      JUBILACION     ARRIESGADO
# 4                      Agrónomo        VIVIENDA    CONSERVADOR
#
#   financial_preference financial_options financial_knowledge  \
# 0               AHORRO               NaN            AVANZADO
# 1               AHORRO               NaN          INTERMEDIO
# 2            INVERSION             OTROS             NINGUNO
# 3            INVERSION              ETFS             NINGUNO
# 4            INVERSION          ACCIONES              BASICO
#
#   investment_period income_source  income_average  expenses_average  \
# 0             1 año   dependiente          548843            412840
# 1           10 años         ambos          823536            473397
# 2           5 meses   dependiente          828342            485594
# 3           5 meses   dependiente          868632            506774
# 4             1 año         ambos          824883            772137
#
#   saving_plan  monthly_contribution
# 0          NO                    40
# 1          SI                    98
# 2          NO                    59
# 3          NO                    39
# 4          SI                    13

# %%
fake = Faker('es_ES')

# Generar nombres y apellidos aleatorios
df['first_name'] = [fake.first_name() for _ in range(len(df))]
df['last_name'] = [fake.last_name() for _ in range(len(df))]

df.head(10)
# Out:
#       first_name last_name      id                         email  user_id  \
# 0        Azucena    Ayllón  718919       rixjomh.povna@gmail.com   718919
# 1  Andrés Felipe   Rodrigo  797826      cvlisikp.boeaf@yahoo.com   797826
# 2           Amor  Figueras  617096       dcii.cmmvcq@outlook.com   617096
# 3            Paz   Vicente  957587  qcepsmwb.xhvukxg@hotmail.com   957587
# 4       Epifanio    Alemán  120636          rknj.rumyz@gmail.com   120636
# 5          María     Vélez  771768    jtdka.unglkjwg@outlook.com   771768
# 6         Chucho  Castillo  134711     fpenirt.xkhbq@outlook.com   134711
# 7       Mercedes    Galván  573330  grqovee.ltgjsdcd@hotmail.com   573330
# 8         Álvaro   Sevilla  961627      ftaic.qocvhw@hotmail.com   961627
# 9       Adelardo    Rivera  428325      ukto.rfyilwa@outlook.com   428325
#
#    age                    occupation financial_goals risk_tolerance  \
# 0   69  Controlador de tráfico aéreo        VIVIENDA       MODERADO
# 1   38                     Filósofos      VACACIONES    CONSERVADOR
# 2   69                           NaN        VIVIENDA     ARRIESGADO
# 3   48                           NaN      JUBILACION     ARRIESGADO
# 4   24                      Agrónomo        VIVIENDA    CONSERVADOR
# 5   62                       Policía           OTROS       MODERADO
# 6   53                    Psicólogos      VACACIONES    CONSERVADOR
# 7   52                     Filósofos       EDUCACION     ARRIESGADO
# 8   24               Modelos de moda      JUBILACION       MODERADO
# 9   35                     Fotógrafo           OTROS       MODERADO
#
#   financial_preference financial_options financial_knowledge  \
# 0               AHORRO               NaN            AVANZADO
# 1               AHORRO               NaN          INTERMEDIO
# 2            INVERSION             OTROS             NINGUNO
# 3            INVERSION              ETFS             NINGUNO
# 4            INVERSION          ACCIONES              BASICO
# 5               AHORRO               NaN             NINGUNO
# 6            INVERSION               CDF          INTERMEDIO
# 7               AHORRO               NaN              BASICO
# 8               AHORRO               NaN              BASICO
# 9            INVERSION          ACCIONES          INTERMEDIO
#
#   investment_period  income_source  income_average  expenses_average  \
# 0             1 año    dependiente          548843            412840
# 1           10 años          ambos          823536            473397
# 2           5 meses    dependiente          828342            485594
# 3           5 meses    dependiente          868632            506774
# 4             1 año          ambos          824883            772137
# 5           5 meses     jubilación          790220            519032
# 6           5 meses     jubilación          501050            410166
# 7           10 años          ambos          488801            389975
# 8           5 meses  independiente          850986            848159
# 9           10 años  independiente          415712            348772
#
#   saving_plan  monthly_contribution
# 0          NO                    40
# 1          SI                    98
# 2          NO                    59
# 3          NO                    39
# 4          SI                    13
# 5          NO                    93
# 6          SI                    71
# 7          NO                    34
# 8          SI                    59
# 9          SI                    41

# %% [markdown]
# ## Verificar valores nulos

# %%
# revisar valores nulos o vacíos 
df.isnull().sum()
# Out:
# first_name                0
# last_name                 0
# id                        0
# email                     0
# user_id                   0
# age                       0
# occupation               46
# financial_goals           0
# risk_tolerance            0
# financial_preference      0
# financial_options       250
# financial_knowledge       0
# investment_period         0
# income_source             0
# income_average            0
# expenses_average          0
# saving_plan               0
# monthly_contribution      0
# dtype: int64

# %%
# tratar los valores nulos 
df['occupation'] = df['occupation'].fillna('Otros')
df['financial_options'] = df['financial_options'].fillna('Opción ahorro')

# %% [markdown]
# ## Verificar duplicados

# %%
# revisar si existen duplicados 
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Formato de las columnas

# %%
# crear funcion para estandarización del texto
def format_sentence_case(df):
    """
    Convierte todo el texto en un DataFrame a formato oración: 
    primera letra en mayúscula, resto en minúsculas.
    """
    for col in df.select_dtypes(include=['object']).columns: 
        df[col] = df[col].astype(str).str.capitalize()  
    return df

df = format_sentence_case(df)

df.head()
# Out:
#       first_name last_name      id                         email  user_id  \
# 0        Azucena    Ayllón  718919       Rixjomh.povna@gmail.com   718919
# 1  Andrés felipe   Rodrigo  797826      Cvlisikp.boeaf@yahoo.com   797826
# 2           Amor  Figueras  617096       Dcii.cmmvcq@outlook.com   617096
# 3            Paz   Vicente  957587  Qcepsmwb.xhvukxg@hotmail.com   957587
# 4       Epifanio    Alemán  120636          Rknj.rumyz@gmail.com   120636
#
#    age                    occupation financial_goals risk_tolerance  \
# 0   69  Controlador de tráfico aéreo        Vivienda       Moderado
# 1   38                     Filósofos      Vacaciones    Conservador
# 2   69                         Otros        Vivienda     Arriesgado
# 3   48                         Otros      Jubilacion     Arriesgado
# 4   24                      Agrónomo        Vivienda    Conservador
#
#   financial_preference financial_options financial_knowledge  \
# 0               Ahorro     Opción ahorro            Avanzado
# 1               Ahorro     Opción ahorro          Intermedio
# 2            Inversion             Otros             Ninguno
# 3            Inversion              Etfs             Ninguno
# 4            Inversion          Acciones              Basico
#
#   investment_period income_source  income_average  expenses_average  \
# 0             1 año   Dependiente          548843            412840
# 1           10 años         Ambos          823536            473397
# 2           5 meses   Dependiente          828342            485594
# 3           5 meses   Dependiente          868632            506774
# 4             1 año         Ambos          824883            772137
#
#   saving_plan  monthly_contribution
# 0          No                    40
# 1          Si                    98
# 2          No                    59
# 3          No                    39
# 4          Si                    13

# %%
# revisar tipo de datos para cada columna
print(df.dtypes)
# Out:
# first_name              object
# last_name               object
# id                       int64
# email                   object
# user_id                  int64
# age                      int64
# occupation              object
# financial_goals         object
# risk_tolerance          object
# financial_preference    object
# financial_options       object
# financial_knowledge     object
# investment_period       object
# income_source           object
# income_average           int64
# expenses_average         int64
# saving_plan             object
# monthly_contribution     int64
# dtype: object

# %% [markdown]
# ### Columnas categóricas

# %% [markdown]
# #### 1

# %%
# revisar columna de objetivo financiero
df['financial_goals'].value_counts()
# Out:
# financial_goals
# Jubilacion               75
# Vacaciones               69
# Educacion                67
# Proyectos_largo_plazo    66
# Imprevistos              64
# Vivienda                 54
# Otros                    54
# Libertad_financiera      51
# Name: count, dtype: int64

# %%
# función para quitar los guiones bajos
def remove_underscores(goal):
    return goal.replace('_', ' ')

df['financial_goals'] = df['financial_goals'].apply(remove_underscores)

# %%
# diccionario para agregar acentos
accent_dict = {
    'Jubilacion': 'Jubilación',
    'Educacion': 'Educación'
}

# reemplazar los valores con acentos usando el diccionario
df['financial_goals'] = df['financial_goals'].apply(lambda x: accent_dict.get(x, x))

# %% [markdown]
# #### 2

# %%
# revisar columna de tolerancia al riesgo
df['risk_tolerance'].value_counts()
# Out:
# risk_tolerance
# Conservador    175
# Moderado       167
# Arriesgado     158
# Name: count, dtype: int64

# %% [markdown]
# #### 3

# %%
# revisar columna de preferencia financiera
df['financial_preference'].value_counts()
# Out:
# financial_preference
# Ahorro       250
# Inversion    250
# Name: count, dtype: int64

# %%
# diccionario para agregar acentos
accent_dict2 = {
    'Inversion': 'Inversión'
}

# reemplazar los valores con acentos usando el diccionario
df['financial_preference'] = df['financial_preference'].apply(lambda x: accent_dict2.get(x, x))

# %% [markdown]
# #### 4

# %%
# revisar columna de opciones financieras
df['financial_options'].value_counts()
# Out:
# financial_options
# Opción ahorro    250
# Otros             48
# Etfs              43
# Cdf               42
# Acciones          39
# Bonos             39
# Cdears            39
# Name: count, dtype: int64

# %%
# diccionario para reemplazar mayúsculas
capital_dict = {
    'Etfs': 'ETFS',
    'Cdf': 'CDF',
    'Cdears': 'CDEARS'
}

# reemplazar los valores usando el diccionario
df['financial_options'] = df['financial_options'].apply(lambda x: capital_dict.get(x, x))

# %% [markdown]
# #### 5

# %%
# revisar columna de conocimiento financiero
df['financial_knowledge'].value_counts()
# Out:
# financial_knowledge
# Intermedio    136
# Basico        136
# Avanzado      115
# Ninguno       113
# Name: count, dtype: int64

# %%
# diccionario para agregar acentos
accent_dict3 = {
    'Basico': 'Básico'
}

# reemplazar los valores con acentos usando el diccionario
df['financial_knowledge'] = df['financial_knowledge'].apply(lambda x: accent_dict3.get(x, x))

# %% [markdown]
# #### 6

# %%
# revisar columna de retorno de inversión
df['investment_period'].value_counts()
# Out:
# investment_period
# 1 año      139
# 1 mes      131
# 10 años    123
# 5 meses    107
# Name: count, dtype: int64

# %%
# función para reemplazar valores
def replace_investment_period(period):
    if '1 mes' in period:
        return 3  # Reemplazar 1 mes por 3 meses
    elif '5 meses' in period:
        return 6  # Reemplazar 5 meses por 6 meses
    elif '1 año' in period:
        return 9  # Reemplazar 1 año por 12 meses
    elif '10 años' in period:
        return 12  # Reemplazar 10 años por +12 meses
    return period 

df['investment_period'] = df['investment_period'].apply(replace_investment_period)

# %% [markdown]
# #### 7

# %%
# revisar columna de fuente de ingresos
df['income_source'].value_counts()
# Out:
# income_source
# Dependiente      169
# Independiente    149
# Ambos            139
# Jubilación        43
# Name: count, dtype: int64

# %% [markdown]
# ### Corregir tipos de datos

# %%
# convertir columnas de texto
df['investment_period'] = df['investment_period'].astype(str)

# convetrir columnas booleanas
df['saving_plan'] = df['saving_plan'].astype(bool)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   first_name            500 non-null    object
#  1   last_name             500 non-null    object
#  2   id                    500 non-null    int64
#  3   email                 500 non-null    object
#  4   user_id               500 non-null    int64
#  5   age                   500 non-null    int64
#  6   occupation            500 non-null    object
#  7   financial_goals       500 non-null    object
#  8   risk_tolerance        500 non-null    object
#  9   financial_preference  500 non-null    object
#  10  financial_options     500 non-null    object
#  11  financial_knowledge   500 non-null    object
#  12  investment_period     500 non-null    object
#  13  income_source         500 non-null    object
#  14  income_average        500 non-null    int64
#  15  expenses_average      500 non-null    int64
#  16  saving_plan           500 non-null    bool
#  17  monthly_contribution  500 non-null    int64
# dtypes: bool(1), int64(6), object(11)
# memory usage: 67.0+ KB

# %%
df.head(10)
# Out:
#       first_name last_name      id                         email  user_id  \
# 0        Azucena    Ayllón  718919       Rixjomh.povna@gmail.com   718919
# 1  Andrés felipe   Rodrigo  797826      Cvlisikp.boeaf@yahoo.com   797826
# 2           Amor  Figueras  617096       Dcii.cmmvcq@outlook.com   617096
# 3            Paz   Vicente  957587  Qcepsmwb.xhvukxg@hotmail.com   957587
# 4       Epifanio    Alemán  120636          Rknj.rumyz@gmail.com   120636
# 5          María     Vélez  771768    Jtdka.unglkjwg@outlook.com   771768
# 6         Chucho  Castillo  134711     Fpenirt.xkhbq@outlook.com   134711
# 7       Mercedes    Galván  573330  Grqovee.ltgjsdcd@hotmail.com   573330
# 8         Álvaro   Sevilla  961627      Ftaic.qocvhw@hotmail.com   961627
# 9       Adelardo    Rivera  428325      Ukto.rfyilwa@outlook.com   428325
#
#    age                    occupation financial_goals risk_tolerance  \
# 0   69  Controlador de tráfico aéreo        Vivienda       Moderado
# 1   38                     Filósofos      Vacaciones    Conservador
# 2   69                         Otros        Vivienda     Arriesgado
# 3   48                         Otros      Jubilación     Arriesgado
# 4   24                      Agrónomo        Vivienda    Conservador
# 5   62                       Policía           Otros       Moderado
# 6   53                    Psicólogos      Vacaciones    Conservador
# 7   52                     Filósofos       Educación     Arriesgado
# 8   24               Modelos de moda      Jubilación       Moderado
# 9   35                     Fotógrafo           Otros       Moderado
#
#   financial_preference financial_options financial_knowledge  \
# 0               Ahorro     Opción ahorro            Avanzado
# 1               Ahorro     Opción ahorro          Intermedio
# 2            Inversión             Otros             Ninguno
# 3            Inversión              ETFS             Ninguno
# 4            Inversión          Acciones              Básico
# 5               Ahorro     Opción ahorro             Ninguno
# 6            Inversión               CDF          Intermedio
# 7               Ahorro     Opción ahorro              Básico
# 8               Ahorro     Opción ahorro              Básico
# 9            Inversión          Acciones          Intermedio
#
#   investment_period  income_source  income_average  expenses_average  \
# 0                 9    Dependiente          548843            412840
# 1                12          Ambos          823536            473397
# 2                 6    Dependiente          828342            485594
# 3                 6    Dependiente          868632            506774
# 4                 9          Ambos          824883            772137
# 5                 6     Jubilación          790220            519032
# 6                 6     Jubilación          501050            410166
# 7                12          Ambos          488801            389975
# 8                 6  Independiente          850986            848159
# 9                12  Independiente          415712            348772
#
#    saving_plan  monthly_contribution
# 0         True                    40
# 1         True                    98
# 2         True                    59
# 3         True                    39
# 4         True                    13
# 5         True                    93
# 6         True                    71
# 7         True                    34
# 8         True                    59
# 9         True                    41

# %%
df.to_csv('financial_profile_iupi.csv', index=False)

# %% [markdown]
# ## Valores inconsistentes o fuera de rango

# %% [markdown]
# ### Columnas numéricas

# %%
df.describe().T

# seleccionar las columnas específicas
columns = ['age', 'investment_period', 'income_average', 'expenses_average', 'monthly_contribution']

# revisar estadísticas
print("\n--- Estadísticas numéricas ---")
df[columns].describe().T
# Out:
# --- Estadísticas numéricas ---
#                       count        mean            std       min        25%  \
# age                   500.0      43.500      14.909950      19.0      30.00
# income_average        500.0  596965.764  179901.286718  282667.0  430338.75
# expenses_average      500.0  444663.714  159997.266087  149838.0  307457.75
# monthly_contribution  500.0      50.128      30.379688       1.0      22.00
#
#                            50%        75%       max
# age                       43.0      55.00      70.0
# income_average        604398.0  756240.75  899213.0
# expenses_average      423790.0  546873.00  869223.0
# monthly_contribution      51.0      78.00     100.0

# %% [markdown]
# **Conclusiones y posibles ajustes:**
#
# * `age` e `investment_period` parecen estar dentro de un rango adecuado.
# * `income_average` y `expenses_average` pueden necesitar un poco más de validación, especialmente si los valores parecen altos. Sería bueno comparar estos valores con estadísticas de ingresos y gastos en el mercado.
# * `monthly_contribution` parece estar bien distribuido y tiene una coherencia razonable.
#
# En resumen, los datos parecen bastante coherentes en general, sería prudente revisar los valores de ingresos y gastos, y entender el contexto de las métricas para asegurar que todo esté alineado con las expectativas de la población representada.

# %% [markdown]
# # Convertir variables categóricas para modelo de machine learning

# %%
categorical_cols = ['financial_goals', 'risk_tolerance', 'financial_preference', 'financial_options', 'financial_knowledge', 'income_source']

df[categorical_cols] = df[categorical_cols].apply(lambda x: x.astype('category'))

print(df.dtypes)
# Out:
# first_name                object
# last_name                 object
# id                         int64
# email                     object
# user_id                    int64
# age                        int64
# occupation                object
# financial_goals         category
# risk_tolerance          category
# financial_preference    category
# financial_options       category
# financial_knowledge     category
# investment_period         object
# income_source           category
# income_average             int64
# expenses_average           int64
# saving_plan                 bool
# monthly_contribution       int64
# dtype: object

# %%
df.to_csv('financial_profile_categorical.csv', index=False)
